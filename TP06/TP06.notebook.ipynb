# %% [markdown]
# ## EXO 01 :

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

data = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.3, random_state=0)

# %%
from sklearn.naive_bayes import GaussianNB

nb_classifier = GaussianNB()
nb_classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
train_score = nb_classifier.score(X_train, y_train)
test_score = nb_classifier.score(X_test, y_test)

# %%
test_data = X_test[:5]
probabilities = nb_classifier.predict_proba(test_data)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

y_pred = nb_classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d")
plt.show()

# %% [markdown]
# ## EXO02 :

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris_data = load_iris()
X_train_iris, X_test_iris, y_train_iris, y_test_iris = train_test_split(iris_data.data, iris_data.target, test_size=0.3, random_state=0)

# %%
from sklearn.model_selection import cross_val_score

cross_val_scores_gaussian = cross_val_score(nb_classifier, iris_data.data, iris_data.target, cv=5)

# %%
print("GaussianNB Cross Validation Scores:", cross_val_scores_gaussian)
# Out:
# GaussianNB Cross Validation Scores: [0.93333333 0.96666667 0.93333333 0.93333333 1.        ]

# %%
sample_data_iris = [[5.85, 4.5, 1, 2.5]]

# Using GaussianNB
predicted_class_gaussian = nb_classifier.predict(sample_data_iris)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       1 sample_data_iris = [[5.85, 4.5, 1, 2.5]]
#       3 # Using GaussianNB
# ----> 4 predicted_class_gaussian = nb_classifier.predict(sample_data_iris)
#
# File c:\Users\DELL Latitude 5330\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\naive_bayes.py:101, in _BaseNB.predict(self, X)
#      87 """
#      88 Perform classification on an array of test vectors X.
#      89
#    (...)
#      98     Predicted target values for X.
#      99 """
#     100 check_is_fitted(self)
# --> 101 X = self._check_X(X)
#     102 jll = self._joint_log_likelihood(X)
#     103 return self.classes_[np.argmax(jll, axis=1)]
#
# File c:\Users\DELL Latitude 5330\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\naive_bayes.py:269, in GaussianNB._check_X(self, X)
#     267 def _check_X(self, X):
# ...
